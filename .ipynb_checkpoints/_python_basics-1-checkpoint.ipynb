# %% [markdown]
# ### python basics

# %% [markdown]
# 1.variabls and data types

# %%
name = "madhu"
age = 22
height = 5.4
is_student=True

# %%
print(name,age,height,is_student)
# Out:
# madhu 22 5.4 True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
a=23
b=44
print(a,b)
# Out:
# 23 44

# %%
number=44
print("number:",number)
# Out:
# number: 44

# %% [markdown]
# ### input and output

# %%
name =input("enter you are name:")
print("name:",name)
# Out:
# enter you are name: madhu reddy
# name: madhu reddy

# %%
a = int(input("enter the number:"))
print("value:",(a * 2))
# Out:
# enter the number: 5
# value: 10

# %%
name ="madhu"
marks =85.5

# %%
print(f"{name} has scored {marks} out of 100")
# Out:
# madhu has scored 85.5 out of 100

# %%
print(f"percentage: {marks: .1f}%")
# Out:
# percentage:  85.5%

# %% [markdown]
# ### operators

# %%
a, b, c= 10,20,30
print(a+b+c,a-b-c,a*b*c)
# Out:
# 60 -40 6000

# %%
a,b = 10,3
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# arithmatic example:

# %%
price=100
quantity=9
tax=0.78
total=price*quantity*(1+tax)
print(total)
# Out:
# 1602.0

# %% [markdown]
# ### logical

# %%
x,y = True,False
print(x and y)
print (x or y)
print(not x)
# Out:
# False
# True
# False

# %%
age = 22
has_id= True 
print(age >= 10 and has_id)
# Out:
# True

# %%
income = 50000
credict_score =720

eligible = income > 30000 and credict_score >= 700
print(eligible)
# Out:
# True

# %% [markdown]
# ### Lists

# %%
numbers =[10,20,30,40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
print(numbers[0])
# Out:
# 10

# %%
numbers = [10,40,50,40]
print(numbers )
# Out:
# [10, 40, 50, 40]

# %% [markdown]
# modify,append,remove lists

# %%
fruits = ["apple","banana","mango"]

# %%
print(fruits [1])
# Out:
# banana

# %%
fruits.append("orange") #add

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
fruits.remove("banana")

# %%
print(fruits)
# Out:
# ['apple', 'mango', 'orange']

# %%
nums = [1,4,5,6,8]
print(len(nums))
print(sum(nums))
print(max(nums), min(nums))
# Out:
# 5
# 24
# 8 1

# %%
nums = [2,10,5,4,1,3]
nums.sort()

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
nums = [10,20,30,40,50]
print(nums[1:4])
# Out:
# [20, 30, 40]

# %%
print(nums[:3])
# Out:
# [10, 20, 30]

# %%
print(nums[:: -1])#revars
# Out:
# [50, 40, 30, 20, 10]

# %%
print(nums[-3:])
# Out:
# [30, 40, 50]

# %%
print(nums[1:4:2])
# Out:
# [20, 40]

# %% [markdown]
# ### loops

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
marks = [70,80,90]
for score in marks:
    print(score)
# Out:
# 70
# 80
# 90
